# %% [markdown]
# <a href="https://colab.research.google.com/github/alogean/Caligrafresque/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
{
  "title": "Psychologie Sociale - Concepts et Études Empiriques (Lectures 7-13)",
  "date_generated": "2024",
  "content": {
    "concepts": {
      "lecture_7_reseaux_communication": {
        "title": "Réseaux de Communication et Leadership",
        "concepts": [
          {
            "nom": "Réseaux de communication",
            "definition": "Structures qui déterminent les possibilités de communication entre les membres d'un groupe",
            "types": {
              "centralise": "Une position centrale contrôle la communication (ex: réseau Y)",
              "decentralise": "Communication équivalente entre toutes les positions (ex: cercle)",
              "autres": "Chaîne, étoile, etc."
            }
          },
          {
            "nom": "Indices de mesure des réseaux",
            "indices": {
              "centralite": "Mesure à quel point une position est centrale",
              "connexite": "Nombre de canaux dont la fermeture isole une position"
            }
          },
          {
            "nom": "Indépendance",
            "definition": "Degré de liberté des individus dans le groupe",
            "caracteristiques": [
              "Plus grande dans les réseaux décentralisés",
              "Plus grande pour la position centrale dans les réseaux centralisés"
            ]
          },
          {
            "nom": "Saturation",
            "definition": "Nombre maximum de messages qu'un individu peut recevoir",
            "caracteristiques": [
              "L'individu central est plus vulnérable à la saturation",
              "Augmente avec la complexité de la tâche"
            ]
          },
          {
            "nom": "Effet des réseaux sur le leadership",
            "reseaux_decentralises": "Aucun leader ne se dégage",
            "reseaux_centralises": "L'individu en position centrale assume le rôle de leader"
          },
          {
            "nom": "Adéquation réseau-tâche",
            "principe": "L'efficacité dépend de l'adéquation entre le réseau et les exigences de la tâche",
            "applications": {
              "taches_simples": "Réseaux centralisés plus efficaces",
              "taches_complexes": "Réseaux décentralisés plus adaptés"
            }
          }
        ]
      },
      "lecture_8_decision_polarisation": {
        "title": "Décision et Polarisation Collectives",
        "concepts": [
          {
            "nom": "Changement des habitudes (Lewin)",
            "experience": "Comparaison entre conférences et discussions de groupe",
            "resultats": {
              "conferences": "3% des femmes servent des abats",
              "discussions": "32% servent des abats après une semaine"
            },
            "facteurs_explicatifs": [
              "Engagement plus fort dans la discussion",
              "Prise de décisions collectives",
              "Connaissance des engagements des autres"
            ]
          },
          {
            "nom": "Prise de risque collective",
            "decouverte": "Les groupes prennent des décisions plus risquées que les individus",
            "procedure": {
              "pre_consensus": "Réponses individuelles",
              "consensus": "Discussion jusqu'à unanimité",
              "post_consensus": "Nouvelles réponses individuelles"
            }
          },
          {
            "nom": "Conditions nécessaires pour l'accroissement du risque",
            "conditions": [
              "Discussion: Simple vote insuffisant",
              "Divergence initiale: Plus la divergence est grande, plus l'effet est fort",
              "Orientation du matériel: Doit favoriser une orientation vers le risque"
            ]
          },
          {
            "nom": "Explications de l'accroissement du risque",
            "theories": {
              "dilution_responsabilite": "L'échec est partagé en groupe",
              "valorisation_risque": "Le risque est valorisé socialement",
              "arguments_persuasifs": "Plus d'arguments pro-risque que pro-prudence"
            }
          },
          {
            "nom": "Polarisation collective",
            "definition": "Phénomène plus général dont l'accroissement du risque n'est qu'un cas particulier",
            "terminologie": {
              "extremisation_collective": "Consensus plus extrême que la moyenne des pré-consensus",
              "polarisation_collective": "Consensus s'approche du pôle qui attirait déjà les réponses"
            },
            "exemple": "Expérience Moscovici-Zavalloni sur les attitudes envers de Gaulle et les Nord-Américains"
          },
          {
            "nom": "Rôle de l'engagement dans l'interaction",
            "facteurs": {
              "disposition_spatiale": "Table carrée vs ligne droite",
              "contraintes_procedurales": "Attention à la procédure réduit la polarisation",
              "contraintes_temporelles": "Limitation du temps réduit la polarisation"
            }
          }
        ]
      },
      "lecture_9_decisions_individuelles": {
        "title": "Décisions Individuelles",
        "concepts": [
          {
            "nom": "Modèle rationnel-économique",
            "principe": "Recherche de la décision optimale",
            "caracteristiques": [
              "Informations complètes et parfaites",
              "Traitement précis et impartial",
              "Considération de toutes les alternatives"
            ]
          },
          {
            "nom": "Modèle administratif",
            "principe": "Reconnaissance des limites de la rationalité humaine",
            "concepts_cles": {
              "rationalite_limitee": "Les décideurs ont des capacités cognitives limitées",
              "decisions_satisfaisantes": "Choix de la première alternative minimalement acceptable",
              "pouvoir_discretionnaire_limite": "Respect des normes morales et éthiques"
            }
          },
          {
            "nom": "Théorie de l'image",
            "principe": "Prise de décision intuitive et automatique",
            "processus": {
              "test_compatibilite": "Cohérence avec les principes, objectifs et plans",
              "test_rentabilite": "Évaluation de l'adéquation"
            }
          },
          {
            "nom": "Effets de cadrage",
            "definition": "Influence de la présentation du problème sur la décision",
            "types": {
              "cadrage_choix_risques": "Aversion au risque pour les gains, recherche de risque pour les pertes",
              "cadrage_attributs": "Évaluation plus positive des caractéristiques présentées positivement",
              "cadrage_objectifs": "Plus grande persuasion par l'information négative"
            }
          },
          {
            "nom": "Utilisation d'heuristiques",
            "heuristique_disponibilite": "Jugements basés sur l'information facilement accessible",
            "heuristique_representativite": "Perception stéréotypée des représentants 'typiques'"
          },
          {
            "nom": "Favori implicite",
            "principe": "Choix d'une option préférée dès le début du processus",
            "candidat_confirmation": "Alternative considérée uniquement pour justifier le favori"
          },
          {
            "nom": "Escalade de l'engagement",
            "definition": "Continuation du soutien à des plans d'action non réussis",
            "cause_principale": "Autojustification et 'sauver la face'"
          }
        ]
      },
      "lectures_10_11_prise_decision_groupe": {
        "title": "Prise de Décision en Groupe",
        "concepts": [
          {
            "nom": "Supériorité des groupes vs individus",
            "historique": "Shaw (1932) montre la supériorité des groupes sur les tâches intellectuelles",
            "remise_en_question": "Lorge-Solomon (1955) - les groupes sont inefficaces compte tenu de leurs ressources"
          },
          {
            "nom": "Modèle de Steiner",
            "formule": "Productivité réelle = Productivité potentielle - Perte de processus",
            "types_pertes": {
              "pertes_coordination": "Mauvaise organisation des efforts",
              "pertes_motivation": "Efforts réduits en groupe"
            }
          },
          {
            "nom": "Brainstorming",
            "regles_osborn": [
              "Générer le maximum d'idées sans se censurer",
              "Pas de jugement sur la qualité",
              "Possibilité d'étendre les idées des autres",
              "Sélection ultérieure"
            ],
            "realite": "Le brainstorming ne fonctionne pas comme prévu",
            "cause_principale": "Blocage de la production - impossible de parler et penser simultanément"
          },
          {
            "nom": "Techniques alternatives",
            "delphi": "Communication écrite uniquement, pas d'interaction verbale",
            "ngt": "Technique du groupe nominal - Génération individuelle puis interaction limitée"
          },
          {
            "nom": "Conflit dans les groupes",
            "plaidoyer_diable": "Critique rigoureuse de la proposition",
            "enquete_dialectique": "Création d'une alternative fondamentalement différente",
            "resultats": "Plaidoyer du diable généralement supérieur"
          },
          {
            "nom": "Effet d'échantillonnage biaisé (Stasser)",
            "probleme": "Les groupes se concentrent sur l'information commune et négligent l'information unique",
            "consequence": "Perte de l'avantage potentiel des groupes"
          },
          {
            "nom": "Règles de décision",
            "taches_discretes": {
              "description": "Peu d'options (ex: jury criminel)",
              "regles": ["Règle majoritaire", "unanimité", "majorité 2/3"]
            },
            "taches_continues": {
              "description": "Nombreuses options (ex: jury civil)",
              "methodes": ["Schémas de jugement social", "Comparaisons appariées"]
            }
          },
          {
            "nom": "Groupthink (Janis)",
            "definition": "Dysfonctionnement des groupes cohésifs visant l'harmonie",
            "conditions_antecedentes": {
              "defauts_structurels": "Isolation, homogénéité",
              "cohesion_groupe": "Suppression des dissensions",
              "stress_externe": "Pression pour agir rapidement"
            },
            "symptomes": [
              "Illusion d'invulnérabilité",
              "Rationalisation collective",
              "Autocensure",
              "Fausse unanimité"
            ]
          },
          {
            "nom": "Groupes de résolution de problèmes",
            "induction_regles": "Comment les groupes dérivent des explications générales",
            "modele_laughlin": [
              "Test d'hypothèses systématique",
              "Règles de sélection des solutions",
              "Processus de démonstration et validation"
            ]
          }
        ]
      },
      "lecture_12_informations_non_partagees": {
        "title": "Informations Non Partagées (Stasser & Titus)",
        "concepts": [
          {
            "nom": "Modèle d'échantillonnage biaisé",
            "principe": "La discussion de groupe est biaisée de deux façons",
            "biais": [
              "Biais en faveur de l'information partagée: Plus probable d'être mentionnée",
              "Biais en faveur des préférences actuelles: Information cohérente avec les préférences initiales"
            ]
          },
          {
            "nom": "Types d'information",
            "information_partagee": "Connue de tous les membres avant la discussion",
            "information_non_partagee": "Détenue par un seul membre"
          },
          {
            "nom": "Distributions d'information",
            "distribution_impartiale": "Ratio pro-A/pro-B similaire pour chaque individu",
            "distribution_legerement_biaisee": "Affaiblit les préférences sans les changer",
            "distribution_fortement_biaisee": "Change les préférences initiales"
          },
          {
            "nom": "Conséquences du biais",
            "consequences": [
              "Les groupes ne mettent pas en commun efficacement leurs informations",
              "L'information unique a peu d'impact sur les décisions",
              "Les préférences initiales sont renforcées plutôt que corrigées"
            ]
          },
          {
            "nom": "Mécanismes explicatifs",
            "mecanismes": [
              "Probabilité de rappel: Plus de membres connaissent l'info → plus probable qu'elle soit mentionnée",
              "Biais de rappel: Information cohérente avec les préférences plus saillante",
              "Contribution sélective: Défense active des préférences initiales"
            ]
          }
        ]
      },
      "lecture_13_biais_cognitifs": {
        "title": "Biais Cognitifs et Heuristiques",
        "concepts": [
          {
            "nom": "Prospect Theory (Kahneman & Tversky)",
            "principes": [
              "Asymétrie gains/pertes: Les pertes pèsent plus que les gains équivalents",
              "Effet de probabilité: Surpondération des faibles probabilités, sous-pondération des moyennes/hautes"
            ]
          },
          {
            "nom": "Effet de framing",
            "definition": "L'orientation contextuelle (positive/négative) modifie la décision",
            "exemple_classique": "Problème de la maladie rare (vies sauvées vs vies perdues)"
          },
          {
            "nom": "Heuristiques de jugement",
            "ancrage_ajustement": "Utilisation d'une valeur de référence pour produire une estimation",
            "types": {
              "ancrage_externe": "Valeur fournie par l'environnement",
              "ancrage_autogenere": "Valeur mobilisée par soi-même"
            },
            "robustesse": "Très robuste pour l'ancrage classique, moins pour les variations contextuelles"
          },
          {
            "nom": "Biais de confirmation",
            "definition": "Production de raisonnements confirmatoires plutôt qu'infirmatoires",
            "exemple": "Tâche 2-4-6 de Wason - recherche de confirmation plutôt que de réfutation"
          },
          {
            "nom": "Modèle de Steiner (processus de groupe)",
            "formule": "Productivité réelle = Potentiel - Pertes de processus",
            "types_pertes": {
              "pertes_coordination": "Mauvaise organisation",
              "pertes_motivation": "Effort réduit"
            }
          },
          {
            "nom": "Paresse sociale",
            "definition": "Réduction de l'effort individuel en situation de groupe",
            "cause": "Réduction de l'identifiabilité et du potentiel d'évaluation"
          },
          {
            "nom": "Free rider effect",
            "definition": "Bénéficier de la performance du groupe sans contribuer",
            "conditions": "Tâches disjonctives où la contribution d'un seul suffit"
          },
          {
            "nom": "Sucker effect",
            "definition": "Réduction de l'effort pour éviter d'être exploité par les autres",
            "mecanisme": "Théorie de l'équité - rééquilibrage des contributions"
          },
          {
            "nom": "Types de tâches (Steiner)",
            "divisibles_vs_unitaires": "Possibilité de subdivision",
            "maximisation_vs_optimisation": "Critère de performance (vitesse vs exactitude)",
            "taches_unitaires": {
              "additives": "Somme des contributions",
              "disjonctives": "Performance du meilleur membre",
              "conjonctives": "Performance du moins bon membre",
              "discretionnaires": "Combinaison complexe"
            }
          }
        ]
      }
    },
    "etudes_empiriques": [
      {
        "nom": "Réseaux de communication",
        "annee": "1950-1951",
        "auteurs": ["Bavelas", "Leavitt"],
        "theorie": "Impact des réseaux sur le leadership et performance",
        "setup": "Groupes travaillant dans différents réseaux (Y, cercle, chaîne) sur tâches de résolution de problèmes",
        "resultats": {
          "reseaux_centralises": "Émergence d'un leader au centre",
          "reseaux_decentralises": "Pas de leader",
          "performance": "Dépend du type de tâche"
        },
        "conclusions": "La structure de communication détermine l'organisation du groupe et l'efficacité selon la nature de la tâche"
      },
      {
        "nom": "Tâche et structure de groupe",
        "annee": 1960,
        "auteurs": ["Faucheux", "Moscovici"],
        "theorie": "Nature de la tâche et émergence du leadership",
        "setup": "Groupes de 4 personnes sur tâches de résolution de problème vs créativité, liberté d'organisation",
        "resultats": {
          "tache_resolution": "Structure centralisée avec leader",
          "tache_creativite": "Structure décentralisée sans leader"
        },
        "conclusions": "Le type de tâche détermine l'organisation spontanée du groupe"
      },
      {
        "nom": "Représentation de la tâche",
        "annee": 1971,
        "auteurs": ["Pabst"],
        "theorie": "Effet de la représentation vs nature objective",
        "setup": "Mêmes tâches avec représentations induites (problème vs créativité)",
        "resultats": {
          "representation_probleme": "Structure centralisée même sur tâche créative",
          "representation_creativite": "Structure décentralisée même sur tâche-problème"
        },
        "conclusions": "La représentation cognitive de la tâche est plus déterminante que sa nature objective"
      },
      {
        "nom": "Changement habitudes alimentaires",
        "annee": 1947,
        "auteurs": ["Lewin"],
        "theorie": "Efficacité des discussions vs conférences",
        "setup": "6 groupes de 13-17 ménagères : 3 groupes conférences vs 3 groupes discussions sur consommation d'abats",
        "resultats": {
          "conferences": "3% servent des abats après 1 semaine",
          "discussions": "32% servent des abats"
        },
        "conclusions": "La discussion de groupe avec prise de décision est plus efficace que l'écoute passive"
      },
      {
        "nom": "Conseils nutritionnels",
        "annee": 1947,
        "auteurs": ["Radke", "Klisurich"],
        "theorie": "Réplication de l'effet Lewin",
        "setup": "Mères recevant conseils individuels (25 min) vs discussions de groupe (6 personnes, même durée) sur nutrition bébé",
        "resultats": "Discussion de groupe significativement supérieure aux conseils individuels après 2-4 semaines",
        "conclusions": "Confirme la supériorité de la méthode de discussion pour le changement de comportement"
      },
      {
        "nom": "Prise de risque collective - Original",
        "annee": 1964,
        "auteurs": ["Kogan", "Wallach"],
        "theorie": "Accroissement du risque en groupe",
        "setup": "Questionnaire 12 items prise de risque : pré-consensus individuel → discussion consensus → post-consensus individuel",
        "resultats": "Consensus et post-consensus systématiquement plus risqués que pré-consensus",
        "conclusions": "Les groupes prennent des décisions plus risquées que les individus"
      },
      {
        "nom": "Conditions de l'accroissement du risque",
        "annee": 1965,
        "auteurs": ["Kogan", "Wallach"],
        "theorie": "Rôle de la discussion",
        "setup": "3 conditions : discussion+consensus, discussion seule, consensus par vote sans discussion",
        "resultats": {
          "discussion_consensus": "Accroissement du risque",
          "discussion_seule": "Accroissement du risque",
          "vote_sans_discussion": "Pas d'accroissement"
        },
        "conclusions": "La discussion est nécessaire pour l'accroissement du risque"
      },
      {
        "nom": "Divergence initiale et risque",
        "annee": 1969,
        "auteurs": ["Ellis", "Spencer", "Olfield"],
        "theorie": "Rôle de la divergence des positions",
        "setup": "Groupes composés avec réponses identiques vs groupes avec réponses variées au pré-consensus",
        "resultats": "Accroissement du risque uniquement dans les groupes avec réponses initiales variées",
        "conclusions": "La divergence initiale est nécessaire pour l'accroissement du risque"
      },
      {
        "nom": "Paris avec probabilités",
        "annee": 1969,
        "auteurs": ["Lambert"],
        "theorie": "Modèle majoritaire",
        "setup": "50 paris sur probabilités 1/10 à 9/10, groupes de 5 avec système de vote jusqu'à consensus",
        "resultats": {
          "moyenne_collective": "0.3485",
          "moyenne_individuelle": "0.3872",
          "correspondance_majoritaire": "À 0.0005 près avec modèle majoritaire"
        },
        "conclusions": "L'accroissement du risque s'explique largement par un effet majoritaire"
      },
      {
        "nom": "Distribution asymétrique",
        "annee": 1969,
        "auteurs": ["Vinokur"],
        "theorie": "Test du modèle majoritaire",
        "setup": "Groupes avec distributions contrôlées : asymétrie vers risque vs vers prudence",
        "resultats": {
          "asymetrie_risque": "Accroissement du risque",
          "asymetrie_prudence": "Pas d'accroissement de prudence mais léger accroissement du risque"
        },
        "conclusions": "Le modèle majoritaire ne rend pas compte de tous les phénomènes"
      },
      {
        "nom": "Polarisation attitudes - De Gaulle",
        "annee": 1969,
        "auteurs": ["Moscovici", "Zavalloni"],
        "theorie": "Extension au-delà du risque",
        "setup": "Échelles d'attitude (De Gaulle, Nord-Américains, jugements Thurstone) avec procédure pré/post-consensus",
        "resultats": {
          "attitudes_de_gaulle": "+0.90 → +1.18",
          "attitudes_nord_americains": "-0.61 → -1.09"
        },
        "conclusions": "La polarisation existe pour tous types d'attitudes, pas seulement le risque"
      },
      {
        "nom": "Polarisation prudence",
        "annee": 1971,
        "auteurs": ["Fraser"],
        "theorie": "Polarisation vers la prudence",
        "setup": "Questionnaire avec 4 items risqués + 4 items orientés prudence",
        "resultats": {
          "items_risques": "Polarisation vers plus de risque",
          "items_prudents": "Polarisation vers plus de prudence"
        },
        "conclusions": "La polarisation va dans la direction de la tendance initiale"
      },
      {
        "nom": "Engagement spatial",
        "annee": 1972,
        "auteurs": ["Moscovici", "Lecuyer"],
        "theorie": "Rôle de l'engagement dans l'interaction",
        "setup": "Groupes assis en carré vs en ligne pendant discussion",
        "resultats": {
          "carre": "Plus d'extrémisation",
          "correlation": "Plus forte divergence initiale/extrémisation"
        },
        "conclusions": "L'arrangement spatial affecte l'intensité de l'interaction et la polarisation"
      },
      {
        "nom": "Contraintes procédurales",
        "annee": 1972,
        "auteurs": ["Moscovici", "Doise", "Dulong"],
        "theorie": "Niveau d'interaction et polarisation",
        "setup": "Groupes avec vs sans consignes sur procédure ou contraintes temporelles",
        "resultats": "Groupes avec contraintes procédurales/temporelles polarisent moins",
        "conclusions": "Les contraintes réduisent l'engagement et favorisent les compromis"
      },
      {
        "nom": "Résolution de problèmes spatiaux",
        "annee": 1970,
        "auteurs": ["Hall", "Watson"],
        "theorie": "Conflit constructif",
        "setup": "Problème de survie lunaire, 15 objets à prioriser. Groupes contrôle vs groupes invités à affronter les divergences",
        "resultats": "Groupes expérimentaux : solutions qualitativement supérieures, meilleure utilisation des ressources, dépassement du niveau du meilleur membre",
        "conclusions": "Le conflit peut être source d'innovation et d'amélioration"
      },
      {
        "nom": "Supériorité des groupes",
        "annee": 1932,
        "auteurs": ["Shaw"],
        "theorie": "Performance groupe vs individu",
        "setup": "Problèmes de puzzle (maris et femmes) : individus vs groupes de 4 personnes",
        "resultats": "3/21 individus résolvent vs 3/5 groupes résolvent le problème",
        "conclusions": "Les groupes sont supérieurs aux individus (interprétation initiale)"
      },
      {
        "nom": "Réanalyse Shaw",
        "annee": 1955,
        "auteurs": ["Lorge", "Solomon"],
        "theorie": "Test du modèle 'meilleur membre'",
        "setup": "Modélisation mathématique des données de Shaw",
        "resultats": "Taux de réussite des groupes (60%) non significativement différent de la prédiction (46%) basée sur le taux individuel",
        "conclusions": "La supériorité des groupes s'explique par la probabilité d'avoir un solveur"
      },
      {
        "nom": "Temps de résolution",
        "annee": 1963,
        "auteurs": ["Davis", "Restle"],
        "theorie": "Processus de groupe et efficacité",
        "setup": "Problèmes intellectuels, mesure du temps de résolution individuel vs groupe",
        "resultats": "Groupes plus lents que prédit par le modèle 'meilleur membre' → modèle 'égalitaire'",
        "conclusions": "Les groupes sont trop égalitaires, perdent du temps avec les non-solveurs"
      },
      {
        "nom": "Brainstorming - Test original",
        "annee": 1958,
        "auteurs": ["Taylor", "Berry", "Block"],
        "theorie": "Efficacité du brainstorming",
        "setup": "Groupes de brainstorming vs individus (groupes nominaux) sur génération d'idées",
        "resultats": "Groupes nominaux supérieurs aux groupes réels de brainstorming",
        "conclusions": "Le brainstorming ne fonctionne pas comme prévu"
      },
      {
        "nom": "Blocage de production",
        "annee": 1987,
        "auteurs": ["Diehl", "Stroebe"],
        "theorie": "Cause de l'échec du brainstorming",
        "setup": "Individus générant des idées seuls vs avec contrainte de parole alternée vs groupes réels",
        "resultats": {
          "contrainte_alternee": "= groupes réels < individus seuls",
          "difference": "Pas de différence contrainte alternée vs groupes"
        },
        "conclusions": "Le blocage de production explique l'échec du brainstorming"
      },
      {
        "nom": "Illusion d'efficacité",
        "annee": "1992-1993",
        "auteurs": ["Stroebe", "Paulus", "et al."],
        "theorie": "Perception vs réalité",
        "setup": "Mesures subjectives vs objectives de performance en brainstorming",
        "resultats": "Participants surestiment leur performance en groupe vs réalité objective",
        "conclusions": "Illusion de l'efficacité de groupe maintient la popularité du brainstorming"
      },
      {
        "nom": "Informations non partagées",
        "annee": 1985,
        "auteurs": ["Stasser", "Titus"],
        "theorie": "Échantillonnage biaisé de l'information",
        "setup": "Caucus politique, 3 candidats, information partagée vs non partagée entre membres. Conditions : partagée, non-partagée/consensus, non-partagée/conflit",
        "resultats": {
          "condition_partagee": "83% choisissent le meilleur candidat (A)",
          "conditions_non_partagees": "18-24% choisissent A",
          "biais": "Vers candidats soutenus par information partagée"
        },
        "conclusions": "Les groupes ne mettent pas en commun efficacement l'information unique"
      },
      {
        "nom": "Rappel d'information",
        "annee": 1985,
        "auteurs": ["Stasser", "Titus"],
        "theorie": "Contenu mémorisé",
        "setup": "Même étude, mesure du rappel pré et post-discussion",
        "resultats": {
          "information_positive_gagnant": "Rappel augmente en conditions non partagées",
          "information_negative": "Pas d'augmentation du rappel"
        },
        "conclusions": "La discussion renforce l'information supportant les préférences initiales"
      },
      {
        "nom": "Ancrage - Pays africains",
        "annee": "1974, 1982",
        "auteurs": ["Tversky", "Kahneman"],
        "theorie": "Heuristique d'ancrage",
        "setup": "Roue de fortune donnant 10% vs 65%, puis estimation % pays africains à l'ONU",
        "resultats": {
          "ancrage_10": "Estimation moyenne = 25%",
          "ancrage_65": "Estimation moyenne = 45%"
        },
        "conclusions": "L'ancrage influence les jugements même quand aléatoire"
      },
      {
        "nom": "Ancrage sportif",
        "annee": 2008,
        "auteurs": ["Critcher", "Gilovich"],
        "theorie": "Ancrage incident",
        "setup": "T-shirt avec numéro 54 vs 94, estimation probabilité de performance sportive",
        "resultats": {
          "numero_54": "Estimation ~52%",
          "numero_94": "Estimation ~60%"
        },
        "conclusions": "L'ancrage fonctionne même de manière incidente"
      },
      {
        "nom": "Réplication ancrage",
        "annee": 2014,
        "auteurs": ["Klein et al. (Many Labs 1)"],
        "theorie": "Robustesse de l'ancrage",
        "setup": "4 questions classiques, N=6344, réplication multi-sites",
        "resultats": "Tailles d'effet : d=2.60, 2.40, 2.05, 1.27",
        "conclusions": "Ancrage classique très robuste"
      },
      {
        "nom": "Ancrage incident - Réplication",
        "annee": 2018,
        "auteurs": ["Klein et al. (Many Labs 2)"],
        "theorie": "Ancrage incident",
        "setup": "Prix smartphone avec chiffre dans le nom, N=6826",
        "resultats": "Taille d'effet : d=0.04",
        "conclusions": "Ancrage incident beaucoup moins robuste"
      },
      {
        "nom": "Tâche 2-4-6",
        "annee": 1966,
        "auteurs": ["Wason"],
        "theorie": "Biais de confirmation",
        "setup": "Découvrir la règle du triplet 2-4-6, possibilité de tester des hypothèses",
        "resultats": "Participants testent majoritairement des cas confirmant leurs hypothèses plutôt qu'infirmant",
        "conclusions": "Tendance naturelle à la confirmation plutôt qu'à la réfutation"
      },
      {
        "nom": "Effet de framing - Maladie",
        "annee": 1981,
        "auteurs": ["Kahneman", "Tversky"],
        "theorie": "Prospect Theory",
        "setup": "Problème maladie 600 personnes, cadrage 'vies sauvées' vs 'vies perdues'",
        "resultats": {
          "cadrage_positif": "72% choisissent option sûre",
          "cadrage_negatif": "78% choisissent option risquée"
        },
        "conclusions": "Le cadrage influence la préférence pour le risque"
      },
      {
        "nom": "Paresse sociale - Cris",
        "annee": 1979,
        "auteurs": ["Latané", "Williams", "Harkins"],
        "theorie": "Paresse sociale",
        "setup": "Crier fort, conditions : seul, groupe de 2, 4, 6 (participants aveugles/sourds)",
        "resultats": {
          "seul": "100%",
          "groupe_2": "71%",
          "groupe_4": "51%",
          "groupe_6": "40%"
        },
        "conclusions": "La motivation diminue avec la taille du groupe"
      },
      {
        "nom": "Identifiabilité",
        "annee": 1981,
        "auteurs": ["Williams", "Harkins", "Latané"],
        "theorie": "Cause de la paresse sociale",
        "setup": "Même tâche avec microphones individuels vs collectifs",
        "resultats": {
          "microphone_collectif": "Effet paresse sociale",
          "microphones_individuels": "Pas d'effet"
        },
        "conclusions": "L'identifiabilité élimine la paresse sociale"
      },
      {
        "nom": "Comparabilité",
        "annee": 1985,
        "auteurs": ["Harkins", "Jackson"],
        "theorie": "Conditions de l'évaluation",
        "setup": "Génération d'utilisations d'objets, manipulation identifiabilité × comparabilité",
        "resultats": "Performance maximale quand identifiable ET comparable",
        "conclusions": "L'évaluation nécessite identifiabilité ET comparabilité"
      },
      {
        "nom": "Free riding",
        "annee": 1983,
        "auteurs": ["Kerr"],
        "theorie": "Dispensabilité de l'effort",
        "setup": "Tâche de pompe à air disjonctive, dyades avec partenaire capable vs incapable",
        "resultats": {
          "partenaire_capable_reussit": "Free riding",
          "partenaire_capable_echoue": "Sucker effect",
          "partenaire_incapable": "Pas de réduction d'effort"
        },
        "conclusions": "L'effort dépend de la dispensabilité perçue"
      },
      {
        "nom": "Taille du groupe et motivation",
        "annee": "1982-1983",
        "auteurs": ["Harkins & Petty", "Kerr & Bruun"],
        "theorie": "Impact de la taille",
        "setup": "Tâches diverses avec groupes de tailles différentes",
        "resultats": {
          "taches_disjonctives_conjonctives": "Baisse d'effort avec taille",
          "taches_additives": "Pas d'effet de la taille"
        },
        "conclusions": "L'effet de taille dépend du type de tâche"
      }
    ],
    "etudes_detaillees": {
      "lecture_7": [
        {
          "nom": "Étude des réseaux de communication",
          "auteurs": ["Bavelas", "Leavitt"],
          "annee": "1950-1951",
          "theorie": "Impact des structures de communication sur l'organisation et la performance des groupes",
          "setup_detaille": "Groupes travaillant dans différents réseaux de communication : centralisé (Y), décentralisé (cercle), chaîne, étoile. Les participants étaient placés dans des positions reliées par des canaux de communication spécifiques. Ils devaient résoudre des tâches en respectant les contraintes de communication imposées par le réseau.",
          "resultats_detailles": {
            "reseaux_centralises": "Émergence systématique d'un leader à la position centrale. Cette personne coordonne les informations et prend les décisions principales. Performance optimale pour les tâches simples.",
            "reseaux_decentralises": "Aucune émergence de leadership centralisé. Communication équivalente entre toutes les positions. Plus de satisfaction des participants mais performance moindre sur tâches simples.",
            "effet_complexite": "Pour les tâches complexes, les réseaux décentralisés deviennent plus efficaces car ils évitent la saturation de la position centrale."
          },
          "conclusions_detaillees": "La structure de communication détermine directement l'organisation du groupe et l'émergence du leadership. Aucun réseau n'est universellement supérieur - l'efficacité dépend de l'adéquation entre la structure du réseau et les exigences de la tâche. Les réseaux centralisés optimisent l'efficacité pour les tâches simples mais créent des risques de saturation pour les tâches complexes."
        },
        {
          "nom": "Étude tâche et structure de groupe",
          "auteurs": ["Faucheux", "Moscovici"],
          "annee": 1960,
          "theorie": "Influence de la nature de la tâche sur l'organisation spontanée des groupes",
          "setup_detaille": "Groupes de 4 personnes avec liberté totale d'organisation. Deux types de tâches : 1) Tâche de résolution de problème (une seule solution correcte), 2) Tâche de créativité (recherche de toutes les solutions possibles). Observation de l'organisation spontanée qui émerge.",
          "resultats_detailles": {
            "tache_resolution": "Émergence systématique d'une structure centralisée avec un leader qui coordonne la recherche de LA bonne réponse. Division claire des rôles avec centralisation des décisions.",
            "tache_creativite": "Développement d'une structure décentralisée sans leader dominant. Participation plus égalitaire de tous les membres. Processus plus démocratique et participatif.",
            "efficacite": "Chaque organisation est optimale pour son type de tâche - centralisation efficace pour convergence, décentralisation efficace pour divergence créative."
          },
          "conclusions_detaillees": "La nature objective de la tâche détermine l'organisation spontanée des groupes. Les groupes s'adaptent naturellement en adoptant la structure la plus appropriée : centralisation pour l'efficacité, décentralisation pour la créativité. Cette adaptation se fait sans instruction externe, suggérant une logique fonctionnelle intrinsèque."
        }
      ],
      "lecture_8": [
        {
          "nom": "Étude changement des habitudes alimentaires",
          "auteurs": ["Lewin"],
          "annee": 1947,
          "theorie": "Efficacité comparative des méthodes de changement de comportement",
          "setup_detaille": "6 groupes de 13-17 ménagères volontaires, 45 minutes par groupe. Condition conférence (3 groupes) : Exposé sur le lien nutrition-effort de guerre, valeur nutritive des abats, recettes de préparation. Condition discussion (3 groupes) : Introduction du problème puis discussion interactive sur les obstacles au changement et moyens de les surmonter. Recettes données seulement après engagement dans le changement.",
          "resultats_detailles": {
            "condition_conference": "3% des femmes avaient servi des abats une semaine après l'intervention",
            "condition_discussion": "32% des femmes avaient servi des abats une semaine après l'intervention",
            "ratio_efficacite": "La discussion de groupe est plus de 10 fois plus efficace que la conférence",
            "persistance": "L'effet se maintient dans le temps selon les suivis ultérieurs"
          },
          "conclusions_detaillees": "La discussion de groupe avec prise de décision collective est drastiquement supérieure à l'information passive. Facteurs explicatifs : 1) Engagement actif vs passivité, 2) Prise de décisions publiques vs privées, 3) Connaissance des engagements mutuels créant une pression sociale, 4) Argumentation personnalisée vs générale. Cette étude établit l'importance de la participation active dans le changement de comportement."
        }
      ],
      "lecture_12": [
        {
          "nom": "Étude informations non partagées - Stasser & Titus",
          "auteurs": ["Stasser", "Titus"],
          "annee": 1985,
          "theorie": "Modèle d'échantillonnage biaisé de l'information en discussion de groupe",
          "setup_detaille": "Simulation de caucus politique, groupes de 4 personnes choisissant entre 3 candidats fictifs à la présidence étudiante. Candidat A : Objectivement meilleur (8 attributs positifs, 4 neutres, 4 négatifs). Candidats B et C : Moins bons (4 positifs, 8 neutres, 4 négatifs chacun). Conditions : Partagée (tous reçoivent toutes les informations), Non-partagée/consensus (information biaisée contre A, pour B), Non-partagée/conflit (information biaisée contre A, divisée entre B et C).",
          "resultats_detailles": {
            "preferences_pre_discussion": {
              "condition_partagee": "67% préfèrent A (le meilleur candidat)",
              "condition_non_partagee_consensus": "25% préfèrent A, 61% préfèrent B",
              "condition_non_partagee_conflit": "21% préfèrent A, 46% B, 33% C"
            },
            "decisions_groupe": {
              "condition_partagee": "83% des groupes choisissent A",
              "condition_non_partagee_consensus": "24% des groupes choisissent A",
              "condition_non_partagee_conflit": "12% des groupes choisissent A"
            },
            "regle_decision": "Candidat avec pluralité initiale gagne dans 81% des cas, seuls 7 groupes choisissent A en conditions non-partagées = tous avaient 2+ membres pro-A initialement"
          },
          "conclusions_detaillees": "Les groupes échouent dramatiquement à mettre en commun l'information non-partagée qui pourrait améliorer leurs décisions. L'information partagée domine la discussion au détriment de l'information unique. La règle de 'pluralité gagne' prévaut, empêchant les groupes de découvrir collectivement la meilleure alternative. Cette étude révèle une limitation fondamentale des groupes de décision."
        }
      ],
      "lecture_13": [
        {
          "nom": "Étude paresse sociale - Intensité des cris",
          "auteurs": ["Latané", "Williams", "Harkins"],
          "annee": 1979,
          "theorie": "Paresse sociale et perte de motivation en groupe",
          "setup_detaille": "Tâche : crier et taper des mains le plus fort possible. Participants rendus aveugles (bandeaux) et sourds (casques) pour éliminer les indices sociaux. Conditions : Seul, groupe de 2, groupe de 4, groupe de 6. Mesure : Intensité sonore en dynes/cm².",
          "resultats_detailles": {
            "seul": "100% (performance de référence)",
            "groupe_2": "71% de l'intensité individuelle",
            "groupe_4": "51% de l'intensité individuelle",
            "groupe_6": "40% de l'intensité individuelle",
            "declin_monotone": "Baisse régulière avec l'augmentation de la taille du groupe",
            "perte_motivationnelle": "Confirmée par élimination des pertes de coordination"
          },
          "conclusions_detaillees": "La motivation individuelle diminue systématiquement avec la taille du groupe, créant une 'paresse sociale'. Cette perte ne s'explique pas par des problèmes de coordination (éliminés expérimentalement) mais par une réduction de la motivation individuelle. Découverte d'un phénomène fondamental des groupes avec implications pratiques importantes."
        }
      ]
    },
    "methodologie": {
      "types_etudes": [
        "Expériences de laboratoire contrôlées",
        "Simulations de situations réelles",
        "Études comparatives individu vs groupe",
        "Réplications multi-sites",
        "Méta-analyses"
      ],
      "mesures_principales": [
        "Performance objective (vitesse, exactitude)",
        "Mesures de motivation (effort, intensité)",
        "Analyses de contenu des discussions",
        "Mesures de rappel et mémoire",
        "Évaluations subjectives et perceptions"
      ],
      "paradigmes_experimentaux": [
        "Pré-test/Post-test avec groupe contrôle",
        "Plans factoriels (2x2, 2x3, etc.)",
        "Mesures répétées",
        "Groupes nominaux vs groupes réels",
        "Manipulation de variables situationnelles"
      ]
    },
    "implications_theoriques": {
      "remises_en_question": [
        "Supériorité automatique des groupes",
        "Rationalité parfaite des décideurs",
        "Efficacité du brainstorming",
        "Modèles de compromis en groupe"
      ],
      "decouvertes_majeures": [
        "Polarisation collective",
        "Paresse sociale",
        "Biais d'échantillonnage informationnel",
        "Effets de cadrage",
        "Heuristiques de jugement"
      ],
      "concepts_emergents": [
        "Pertes de processus",
        "Rationalité limitée",
        "Identifiabilité et évaluation",
        "Dispensabilité de l'effort",
        "Engagement dans l'interaction"
      ]
    },
    "applications_pratiques": {
      "conception_groupes_travail": [
        "Optimiser la taille selon le type de tâche",
        "Assurer l'identifiabilité des contributions",
        "Structurer les discussions pour éviter les biais",
        "Gérer les réseaux de communication"
      ],
      "prise_decision": [
        "Éviter les effets de cadrage",
        "Structurer l'échange d'informations",
        "Gérer les conflits constructivement",
        "Prévenir le groupthink"
      ],
      "changement_comportement": [
        "Privilégier la discussion à l'information passive",
        "Créer l'engagement par la participation",
        "Utiliser la pression sociale positive",
        "Personnaliser les approches"
      ]
    }
  }
}
```
# Out:
#   File "<ipython-input-1-2eb5cf865108>", line 886
#     ```
#     ^
# SyntaxError: invalid syntax
